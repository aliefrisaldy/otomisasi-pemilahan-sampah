# %% [markdown]
# tes deteksi via gambar

# %%
from ultralytics import YOLO

model = YOLO("runs/detect/yolov8s_trash_sorting/weights/best.pt")

results = model.predict(source="D:\grinding\project\Otomisasi Pemilahan Sampah Berbasil Visi Komputer\data test", show=True, save=True)
# Out:
# <>:5: SyntaxWarning: invalid escape sequence '\g'
# <>:5: SyntaxWarning: invalid escape sequence '\g'
# C:\Users\ryhnd\AppData\Local\Temp\ipykernel_20724\1139858427.py:5: SyntaxWarning: invalid escape sequence '\g'
#   results = model.predict(source="D:\grinding\project\Otomisasi Pemilahan Sampah Berbasil Visi Komputer\data test", show=True, save=True)
# image 1/1 D:\grinding\project\Otomisasi Pemilahan Sampah Berbasil Visi Komputer\data test\image.png: 608x640 1 Plastik, 80.5ms
# Speed: 12.1ms preprocess, 80.5ms inference, 27.3ms postprocess per image at shape (1, 3, 608, 640)
# Results saved to D:\grinding\project\Otomisasi Pemilahan Sampah Berbasil Visi Komputer\runs\detect\predict3
